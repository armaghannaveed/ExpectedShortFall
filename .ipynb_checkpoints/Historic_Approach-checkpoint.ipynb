# %%
import pandas as pd
import numpy as np
#oof

# %%
company_dataset = pd.read_csv("Data/CRSP_stocks_clean.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 company_dataset = pd.read_csv("Data/CRSP_stocks_clean.csv")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
company_dataset
# Out:
#          Unnamed: 0        date TICKER     CUSIP      PRC       RET  \
# 0              1718  2000-01-03    AIR     36110  17.5625 -0.020906
# 1             10251  2000-01-04    AIR     36110  17.6250  0.003559
# 2             18784  2000-01-05    AIR     36110  17.8125  0.010638
# 3             27320  2000-01-06    AIR     36110  17.9375  0.007018
# 4             35852  2000-01-07    AIR     36110  18.5625  0.034843
# ...             ...         ...    ...       ...      ...       ...
# 8109235    42531451  2022-12-23     TK  Y8564W10   4.5800 -0.002179
# 8109236    42540998  2022-12-27     TK  Y8564W10   4.5700 -0.002183
# 8109237    42550538  2022-12-28     TK  Y8564W10   4.3100 -0.056893
# 8109238    42560071  2022-12-29     TK  Y8564W10   4.4300  0.027842
# 8109239    42569586  2022-12-30     TK  Y8564W10   4.5400  0.024831
#
#                VOL     BID     ASK    SHROUT
# 0         109000.0  17.375  17.750   27401.0
# 1          51700.0  17.375  17.875   27401.0
# ...

# %%
company_dataset.describe()
# Out:
#          Unnamed: 0           PRC           RET           VOL           BID  \
# count  8.109240e+06  8.109240e+06  8.109240e+06  8.109236e+06  8.011387e+06
# mean   2.090025e+07  1.681014e+02  6.724031e-04  1.728679e+06  1.695450e+02
# std    1.184000e+07  5.619363e+03  3.072010e-02  8.122187e+06  5.646957e+03
# min    7.000000e+00 -3.941050e+02 -8.666670e-01  0.000000e+00  1.000000e-02
# 25%    1.079093e+07  1.084000e+01 -1.030200e-02  4.000200e+04  1.102000e+01
# 50%    2.074491e+07  2.387500e+01  0.000000e+00  2.162405e+05  2.399000e+01
# 75%    3.089239e+07  4.561000e+01  1.080900e-02  9.836855e+05  4.578000e+01
# max    4.257144e+07  5.391800e+05  5.985491e+00  1.226791e+09  5.391600e+05
#
#                 ASK        SHROUT
# count  8.011387e+06  8.109240e+06
# mean   1.698529e+02  1.894705e+05
# std    5.654736e+03  6.357353e+05
# min    3.200000e-02  1.000000e+01
# 25%    1.110000e+01  1.638900e+04
# 50%    2.408000e+01  4.296800e+04
# 75%    4.587000e+01  1.279820e+05
# ...
